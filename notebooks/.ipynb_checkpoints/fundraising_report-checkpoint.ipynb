# %%
import pandas as pd
from django_pandas.io import read_frame

# %%
from mec.models import Contribution, Address, Contributor, District

# %%
Address.objects.filter(coordinates__contained=District.objects.get(number=95).boundaries)
# Out:
# <QuerySet [<Address: 4656 Baumgartner Rd, Saint Louis, MO 63129>, <Address: 3114 Woodbridge Est Drive, Oakville, MO 63129>, <Address: 2957 Sean Pkwy, St Louis, MO 63129-4512>, <Address: 5909 Cardinal Creek Dr, St Louis, MO 63129-4662>, <Address: 2404 Boardwalk Place Drive, St Louis, MO 63129-4853>, <Address: 5806 Southcrest Way, St Louis, MO 63129>, <Address: 3775 Gumtree Ln, St Louis, MO 63129>, <Address: 7186 Christopher, St Louis, MO 63129>, <Address: 3520 Jeffco Blvd, Arnold, MO 63010>, <Address: 4029 Jeffco Blvd, Arnold, MO 63010>, <Address: 5921 Briarmist Pl, Saint Louis, MO 63128-4427>, <Address: 810 Jeffco Blvd, Arnold, MO 63010>, <Address: Mehlville, St Louis, MO 63129>, <Address: 6134 Pathfinder Dr, St Louis, MO 63129>, <Address: 5091 Baumgartner Road, St Louis, MO 63129>, <Address: 4173 Fairburn Ct, Saint Louis, MO 631297238>, <Address: 4949 Karington Place Dr, Saint Louis, MO 631297101>, <Address: 5132 Crosswood Dr, St Louis, MO 63129>, <Address: 2687 Sanders, St Louis, MO 63129>, <Address: 5050 Lampglow, St Louis, MO 63129>, '...(remaining elements truncated)...']>

# %%
donors_95th = Contributor.objects.filter(address__coordinates__contained=District.objects.get(number=95).boundaries)

# %%
contributions_95th = Contribution.objects.filter(contributor__address__coordinates__contained=District.objects.get(number=95).boundaries)

# %%
df = read_frame(contributions_95th, fieldnames=[
    'date',
    'recipient__name':'Recipient',
    'contributor__committee__name',
    'contriburtor__company__name',
    'contributor__individual__first_name':'First',
    'contributor__individual__last_name':'Last',
    'contributor__individual__employer':'Employer',
    'contributor__individual__occupation':'Occupation',
    'contributor__address__address1':'Address'
    
])

# %%
df
# Out:
#                                 committee__name  \
# 0       Plasterer  Cement Masons Local Pac Fund
# 1      Plasterers And Cement Masons Local 3 Pac
# 2                                          None
# 3    Operative Plasterers And Cement Masons 518
# 4                                          None
# ..                                          ...
# 956                                        None
# 957                                        None
# 958                                        None
# 959                                        None
# 960                                        None
#
#                                 company__name individual__first_name  \
# 0                                        None                   None
# 1                                        None                   None
# 2     Plasterer  Cement Masons Local Pac Fund                   None
# 3                                        None                   None
# 4    Plasterers  Cement Masons Local Pac Fund                   None
# ..                                        ...                    ...
# 956                                      None                  Susan
# 957                                      None                  Vinke
# 958                        Spavale Realty Llc                   None
# 959                                      None                Michael
# 960                                      None                   Mary
#
#     individual__last_name
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# ..                    ...
# 956            Freidmeyer
# 957              Palamand
# 958                  None
# 959                Curtin
# 960                Mankus
#
# [961 rows x 4 columns]

# %%
df = pd.read_csv('mo_83.csv',index_col=0).rename(columns={'amount':'Amount',
                                 'date':'Date',
                                 'recipient__name':'Recipient',
                                 'contributor__individual__first_name':'First',
                                'contributor__individual__last_name':'Last',
                                'contributor__individual__employer':'Employer',
                                'contributor__individual__occupation':'Occupation',
                                'contributor__address__address1':'Address'})

# %%
df1 = df.groupby(['First','Last','Employer','Occupation','Address']).agg({'Amount':['mean','count','sum'],'Recipient': lambda x: pd.Series.mode(x)[0], 'Date':'max'}).sort_values(by=('Amount','count'),ascending=False)
df1.columns = df1.columns.get_level_values(1)
df1 = df1.rename(columns={'sum':'Total Amount ($)','count':'# of Donations','mean':'Avg Donation ($)','<lambda>':'Most Common Recipient','max':'Most Recent Donation'})
df1
# Out:
#                                                                                           Avg Donation ($)  \
# First     Last      Employer          Occupation                   Address
# Jeanne    Kirkton   Requested         Requested                    659 Tuxedo                   130.910000
# Michele   Bunch     Farmers Insurance Field Claims Supervisor      3721 Regal Pl                  7.676471
# Beth      Newman    Kipp Saint Louis  Speech Language Pathologist  7401 Gayola Place             32.435412
# Alexander Euzarraga AtT Services Inc  Associate DirectorAccounting 8901 Cardinal Terrace         23.170732
# Tom       Schawang  Major Brands      Cfo  Major Brands            103 Glen Road                 54.250000
# ...                                                                                                    ...
# Jim       Schallom  Sherwood Forest   Nonprofit Management         6029 Hartford Street         100.000000
#           Mittino   City Of St Louis  Manager                      5032 Murdoch Ave             100.000000
#           Mcgivney  Retired           Retired                      346 Tulip                     75.000000
#           Mccarthy  Not Employed      Not Employed                 4964 Fyler Av Apt A           50.000000
# Zachary   Tebb      St AnthonyS       Physician                    137 S Maple Ave              100.000000
#
#                                                                                           # of Donations  \
# First     Last      Employer          Occupation                   Address
# Jeanne    Kirkton   Requested         Requested                    659 Tuxedo                         92
# Michele   Bunch     Farmers Insurance Field Claims Supervisor      3721 Regal Pl                      85
# Beth      Newman    Kipp Saint Louis  Speech Language Pathologist  7401 Gayola Place                  85
# Alexander Euzarraga AtT Services Inc  Associate DirectorAccounting 8901 Cardinal Terrace              82
# Tom       Schawang  Major Brands      Cfo  Major Brands            103 Glen Road                      80
# ...                                                                                                  ...
# Jim       Schallom  Sherwood Forest   Nonprofit Management         6029 Hartford Street                1
#           Mittino   City Of St Louis  Manager                      5032 Murdoch Ave                    1
#           Mcgivney  Retired           Retired                      346 Tulip                           1
#           Mccarthy  Not Employed      Not Employed                 4964 Fyler Av Apt A                 1
# Zachary   Tebb      St AnthonyS       Physician                    137 S Maple Ave                     1
#
#                                                                                           Total Amount ($)  \
# First     Last      Employer          Occupation                   Address
# Jeanne    Kirkton   Requested         Requested                    659 Tuxedo                     12043.72
# Michele   Bunch     Farmers Insurance Field Claims Supervisor      3721 Regal Pl                    652.50
# Beth      Newman    Kipp Saint Louis  Speech Language Pathologist  7401 Gayola Place               2757.01
# Alexander Euzarraga AtT Services Inc  Associate DirectorAccounting 8901 Cardinal Terrace           1900.00
# Tom       Schawang  Major Brands      Cfo  Major Brands            103 Glen Road                   4340.00
# ...                                                                                                    ...
# Jim       Schallom  Sherwood Forest   Nonprofit Management         6029 Hartford Street             100.00
#           Mittino   City Of St Louis  Manager                      5032 Murdoch Ave                 100.00
#           Mcgivney  Retired           Retired                      346 Tulip                         75.00
#           Mccarthy  Not Employed      Not Employed                 4964 Fyler Av Apt A               50.00
# Zachary   Tebb      St AnthonyS       Physician                    137 S Maple Ave                  100.00
#
#                                                                                                                      Most Common Recipient  \
# First     Last      Employer          Occupation                   Address
# Jeanne    Kirkton   Requested         Requested                    659 Tuxedo                                 IstMo Nominee Pac Number Two
# Michele   Bunch     Farmers Insurance Field Claims Supervisor      3721 Regal Pl                                        Feapac Of Missouri
# Beth      Newman    Kipp Saint Louis  Speech Language Pathologist  7401 Gayola Place                               Elad Gross For Missouri
# Alexander Euzarraga AtT Services Inc  Associate DirectorAccounting 8901 Cardinal Terrace  AtT Missouri Employee Political Action Committee
# Tom       Schawang  Major Brands      Cfo  Major Brands            103 Glen Road                   Major Brands Political Action Committee
# ...                                                                                                                                    ...
# Jim       Schallom  Sherwood Forest   Nonprofit Management         6029 Hartford Street                                        Team Clancy
#           Mittino   City Of St Louis  Manager                      5032 Murdoch Ave                          Citizens For Tishaura O Jones
#           Mcgivney  Retired           Retired                      346 Tulip                       Sarah Unsicker For State Representative
#           Mccarthy  Not Employed      Not Employed                 4964 Fyler Av Apt A                            Megan Green For St Louis
# Zachary   Tebb      St AnthonyS       Physician                    137 S Maple Ave                                  Patterson For Missouri
#
#                                                                                          Most Recent Donation
# First     Last      Employer          Occupation                   Address
# Jeanne    Kirkton   Requested         Requested                    659 Tuxedo                      2020-03-31
# Michele   Bunch     Farmers Insurance Field Claims Supervisor      3721 Regal Pl                   2019-03-14
# Beth      Newman    Kipp Saint Louis  Speech Language Pathologist  7401 Gayola Place               2020-03-31
# Alexander Euzarraga AtT Services Inc  Associate DirectorAccounting 8901 Cardinal Terrace           2020-03-20
# Tom       Schawang  Major Brands      Cfo  Major Brands            103 Glen Road                   2020-03-19
# ...                                                                                                       ...
# Jim       Schallom  Sherwood Forest   Nonprofit Management         6029 Hartford Street            2018-06-08
#           Mittino   City Of St Louis  Manager                      5032 Murdoch Ave                2014-03-14
#           Mcgivney  Retired           Retired                      346 Tulip                       2016-10-03
#           Mccarthy  Not Employed      Not Employed                 4964 Fyler Av Apt A             2019-02-20
# Zachary   Tebb      St AnthonyS       Physician                    137 S Maple Ave                 2018-03-01
#
# [1673 rows x 5 columns]

# %%
df1.to_csv('mo_83_clean.csv')

# %%
df2 = pd.read_csv('vanphonenumbers.csv').rename(columns={'Last Name':'Last','First Name':'First'})
df4 = pd.read_csv('vanphonenumbers2.csv').rename(columns={'Last Name':'Last','First Name':'First'})
df5 = pd.read_csv('vanphonenumbers3.csv',low_memory=False).rename(columns={'Last Name':'Last','First Name':'First'})
df2['Phone Number'] = df2['Phone Number'].astype(str)
df4['Phone Number'] = df4['Phone Number'].astype(str)
# df5['Phone Number'] = df5['Phone Number'].astype(str)
# df6 = df2.merge(df4,left_on='Phone Number')
df6 = pd.concat([df2,df4,df5]).drop_duplicates()

# %%
df2 = df6
df2 = df2[['First','Last','Phone Number','Is Cell?','Is Preferred?']]
df2['First'] = df2['First'].apply(lambda x: x.split()[0])
# df4 = df4[['First','Last','Phone Number','Is Cell?','Is Preferred?']]
# df4['First'] = df4['First'].apply(lambda x: x.split()[0])
# df5 = df5[['First','Last','Phone Number','Is Cell?','Is Preferred?']]
# df5['First'] = df5['First'].apply(lambda x: x.split()[0])
df3 = df1.reset_index().merge(df2,on=['First','Last'],how='left') #.merge(df4,on=['First','Last',],how='left').merge(df5,on=['First','Last',],how='left')
df3['Avg Donation ($)'] = df3['Avg Donation ($)'].round(2)
df3['Total Amount ($)'] = df3['Total Amount ($)'].round().astype(int)
# df3['Phone Number'] = df3['Phone Number_x'].combine_first(df3['Phone Number_y'])
# df3 = df3.drop(columns=['Phone Number_x', 'Phone Number_y'])
# df3['Is Cell?'] = df3['Is Cell?_x'].combine_first(df3['Is Cell?_y'])
# df3 = df3.drop(columns=['Is Cell?_x', 'Is Cell?_y'])
# df3['Is Preferred?'] = df3['Is Preferred?_x'].combine_first(df3['Is Preferred?_y'])
# df3 = df3.drop(columns=['Is Preferred?_x', 'Is Preferred?_y'])
df3 = df3.fillna('NA')
df3
# Out:
# /home/tyler/.virtualenvs/thesis/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         First      Last           Employer                   Occupation  \
# 0      Jeanne   Kirkton          Requested                    Requested
# 1     Michele     Bunch  Farmers Insurance      Field Claims Supervisor
# 2     Michele     Bunch  Farmers Insurance      Field Claims Supervisor
# 3        Beth    Newman   Kipp Saint Louis  Speech Language Pathologist
# 4        Beth    Newman   Kipp Saint Louis  Speech Language Pathologist
# ...       ...       ...                ...                          ...
# 3918      Jim  Schallom    Sherwood Forest         Nonprofit Management
# 3919      Jim   Mittino   City Of St Louis                      Manager
# 3920      Jim  Mcgivney            Retired                      Retired
# 3921      Jim  Mccarthy       Not Employed                 Not Employed
# 3922  Zachary      Tebb        St AnthonyS                    Physician
#
#                    Address  Avg Donation ($)  # of Donations  \
# 0               659 Tuxedo            130.91              92
# 1            3721 Regal Pl              7.68              85
# 2            3721 Regal Pl              7.68              85
# 3        7401 Gayola Place             32.44              85
# 4        7401 Gayola Place             32.44              85
# ...                    ...               ...             ...
# 3918  6029 Hartford Street            100.00               1
# 3919      5032 Murdoch Ave            100.00               1
# 3920             346 Tulip             75.00               1
# 3921   4964 Fyler Av Apt A             50.00               1
# 3922       137 S Maple Ave            100.00               1
#
#       Total Amount ($)                    Most Common Recipient  \
# 0                12044             IstMo Nominee Pac Number Two
# 1                  652                       Feapac Of Missouri
# 2                  652                       Feapac Of Missouri
# 3                 2757                  Elad Gross For Missouri
# 4                 2757                  Elad Gross For Missouri
# ...                ...                                      ...
# 3918               100                              Team Clancy
# 3919               100            Citizens For Tishaura O Jones
# 3920                75  Sarah Unsicker For State Representative
# 3921                50                 Megan Green For St Louis
# 3922               100                   Patterson For Missouri
#
#      Most Recent Donation Phone Number           Is Cell? Is Preferred?
# 0              2020-03-31           NA                 NA            NA
# 1              2019-03-14  13144060059      Verified Cell             0
# 2              2019-03-14  16363299572  Likely Not a Cell             0
# 3              2020-03-31  13146013113  Likely Not a Cell             0
# 4              2020-03-31  13143153425        Likely Cell             0
# ...                   ...          ...                ...           ...
# 3918           2018-06-08           NA                 NA            NA
# 3919           2014-03-14           NA                 NA            NA
# 3920           2016-10-03           NA                 NA            NA
# 3921           2019-02-20           NA                 NA            NA
# 3922           2018-03-01           NA                 NA            NA
#
# [3923 rows x 13 columns]

# %%
len(df3[df3['Phone Number']!='NA']) #.drop_duplicates(subset=['First','Last']))
# Out:
# 2891

# %%
df3.to_csv('MO83_w_numbers.csv',index=False)

# %%
pd.unique(df3[['Last','First']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-278-3c6bc8703ba6> in <module>
# ----> 1 pd.unique(df3[['Last','First']])
#
# ~/.virtualenvs/thesis/lib/python3.6/site-packages/pandas/core/algorithms.py in unique(values)
#     370     """
#     371
# --> 372     values = _ensure_arraylike(values)
#     373
#     374     if is_extension_array_dtype(values):
#
# ~/.virtualenvs/thesis/lib/python3.6/site-packages/pandas/core/algorithms.py in _ensure_arraylike(values)
#     212             if isinstance(values, tuple):
#     213                 values = list(values)
# --> 214             values = construct_1d_object_array_from_listlike(values)
#     215         else:
#     216             values = np.asarray(values)
#
# ~/.virtualenvs/thesis/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in construct_1d_object_array_from_listlike(values)
#    1477     # making a 1D array that contains list-likes is a bit tricky:
#    1478     result = np.empty(len(values), dtype="object")
# -> 1479     result[:] = values
#    1480     return result
#    1481
#
# ValueError: could not broadcast input array from shape (3923,2) into shape (3923)

# %%
df3.drop_duplicates(subset=['First','Last','Employer','Occupation']).reset_index().loc[500,['Last','First']]
# Out:
# Last     Larose
# First      Lisa
# Name: 500, dtype: object
